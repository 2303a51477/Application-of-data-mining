# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a51477/Application-of-data-mining/blob/main/assignment_2_1477.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path = "/content/titanic_train.csv"
df = pd.read_csv(file_path)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print("\nNull Values:")
print(df.isnull().sum())
# Out:
# Null Values:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
numerical_cols = df.select_dtypes(include=['float64', 'int64'])

# %%
print("\nStatistics:")
print("Mean:")
print(numerical_cols.mean())
# Out:
# Statistics:
# Mean:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %%
normalized_data = (numerical_cols - numerical_cols.min()) / (numerical_cols.max() - numerical_cols.min())
print("\nNormalized Data (First 5 rows):")
print(normalized_data.head())
# Out:
# Normalized Data (First 5 rows):
#    PassengerId  Survived  Pclass       Age  SibSp  Parch      Fare
# 0     0.000000       0.0     1.0  0.271174  0.125    0.0  0.014151
# 1     0.001124       1.0     0.0  0.472229  0.125    0.0  0.139136
# 2     0.002247       1.0     1.0  0.321438  0.000    0.0  0.015469
# 3     0.003371       1.0     0.0  0.434531  0.125    0.0  0.103644
# 4     0.004494       0.0     1.0  0.434531  0.000    0.0  0.015713

# %%
df.drop_duplicates(inplace=True)

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['Age'], df['Fare'], 'bo', alpha=0.5)
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Age vs Fare')
plt.show()

# %%
sns.countplot(x='Pclass', data=df)
plt.title('Passenger Class Distribution')
plt.show()

# %%
plt.hist(df['Age'], bins=20, edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.show()

# %%
df_sorted = df.sort_values(by='Age')
df_sorted['Cumulative Survival'] = df_sorted['Survived'].cumsum()
plt.plot(df_sorted['Age'], df_sorted['Cumulative Survival'])
plt.xlabel('Age')
plt.ylabel('Cumulative Survival')
plt.title('Cumulative Survival by Age')
plt.show()

# %%
sns.boxplot(x='Pclass', y='Fare', data=df)
plt.title('Fare Distribution by Passenger Class')
plt.show()

# %%
survival_counts = df['Survived'].value_counts()
plt.pie(survival_counts, labels=['Did Not Survive', 'Survived'], autopct='%1.1f%%', colors=['red', 'green'])
plt.title('Survival Ratio')
plt.show()
